# %% [markdown]
# <a href="https://colab.research.google.com/github/AkAsH-2pac/car-class-and-price/blob/main/car_price.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
df = pd.read_csv("/content/drive/MyDrive/cars_price.csv")

# %%
import numpy as np
import pandas as pd

# %%
df
# Out:
#      symboling normalized-losses         make fuel-type aspiration  \
# 0            3                 ?  alfa-romero       gas        std
# 1            3                 ?  alfa-romero       gas        std
# 2            1                 ?  alfa-romero       gas        std
# 3            2               164         audi       gas        std
# 4            2               164         audi       gas        std
# ..         ...               ...          ...       ...        ...
# 200         -1                95        volvo       gas        std
# 201         -1                95        volvo       gas      turbo
# 202         -1                95        volvo       gas        std
# 203         -1                95        volvo    diesel      turbo
# 204         -1                95        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0            two  convertible          rwd           front        88.6  ...
# 1            two  convertible          rwd           front        88.6  ...
# 2            two    hatchback          rwd           front        94.5  ...
# 3           four        sedan          fwd           front        99.8  ...
# 4           four        sedan          4wd           front        99.4  ...
# ..           ...          ...          ...             ...         ...  ...
# 200         four        sedan          rwd           front       109.1  ...
# 201         four        sedan          rwd           front       109.1  ...
# 202         four        sedan          rwd           front       109.1  ...
# 203         four        sedan          rwd           front       109.1  ...
# 204         four        sedan          rwd           front       109.1  ...
#
#      engine-size  fuel-system  bore  stroke compression-ratio horsepower  \
# 0            130         mpfi  3.47    2.68               9.0        111
# 1            130         mpfi  3.47    2.68               9.0        111
# 2            152         mpfi  2.68    3.47               9.0        154
# 3            109         mpfi  3.19     3.4              10.0        102
# 4            136         mpfi  3.19     3.4               8.0        115
# ..           ...          ...   ...     ...               ...        ...
# 200          141         mpfi  3.78    3.15               9.5        114
# 201          141         mpfi  3.78    3.15               8.7        160
# 202          173         mpfi  3.58    2.87               8.8        134
# 203          145          idi  3.01     3.4              23.0        106
# 204          141         mpfi  3.78    3.15               9.5        114
#
#      peak-rpm city-mpg highway-mpg  price
# 0        5000       21          27  13495
# 1        5000       21          27  16500
# 2        5000       19          26  16500
# 3        5500       24          30  13950
# 4        5500       18          22  17450
# ..        ...      ...         ...    ...
# 200      5400       23          28  16845
# 201      5300       19          25  19045
# 202      5500       18          23  21485
# 203      4800       26          27  22470
# 204      5400       19          25  22625
#
# [205 rows x 26 columns]

# %%
df.shape
# Out:
# (205, 26)

# %%
from sklearn import preprocessing

# %%
Label_Encoder = preprocessing.LabelEncoder()

# %%
df
# Out:
#      symboling normalized-losses         make fuel-type aspiration  \
# 0            3                 ?  alfa-romero       gas        std
# 1            3                 ?  alfa-romero       gas        std
# 2            1                 ?  alfa-romero       gas        std
# 3            2               164         audi       gas        std
# 4            2               164         audi       gas        std
# ..         ...               ...          ...       ...        ...
# 200         -1                95        volvo       gas        std
# 201         -1                95        volvo       gas      turbo
# 202         -1                95        volvo       gas        std
# 203         -1                95        volvo    diesel      turbo
# 204         -1                95        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0            two  convertible          rwd           front        88.6  ...
# 1            two  convertible          rwd           front        88.6  ...
# 2            two    hatchback          rwd           front        94.5  ...
# 3           four        sedan          fwd           front        99.8  ...
# 4           four        sedan          4wd           front        99.4  ...
# ..           ...          ...          ...             ...         ...  ...
# 200         four        sedan          rwd           front       109.1  ...
# 201         four        sedan          rwd           front       109.1  ...
# 202         four        sedan          rwd           front       109.1  ...
# 203         four        sedan          rwd           front       109.1  ...
# 204         four        sedan          rwd           front       109.1  ...
#
#      engine-size  fuel-system  bore  stroke compression-ratio horsepower  \
# 0            130         mpfi  3.47    2.68               9.0        111
# 1            130         mpfi  3.47    2.68               9.0        111
# 2            152         mpfi  2.68    3.47               9.0        154
# 3            109         mpfi  3.19     3.4              10.0        102
# 4            136         mpfi  3.19     3.4               8.0        115
# ..           ...          ...   ...     ...               ...        ...
# 200          141         mpfi  3.78    3.15               9.5        114
# 201          141         mpfi  3.78    3.15               8.7        160
# 202          173         mpfi  3.58    2.87               8.8        134
# 203          145          idi  3.01     3.4              23.0        106
# 204          141         mpfi  3.78    3.15               9.5        114
#
#      peak-rpm city-mpg highway-mpg  price
# 0        5000       21          27  13495
# 1        5000       21          27  16500
# 2        5000       19          26  16500
# 3        5500       24          30  13950
# 4        5500       18          22  17450
# ..        ...      ...         ...    ...
# 200      5400       23          28  16845
# 201      5300       19          25  19045
# 202      5500       18          23  21485
# 203      4800       26          27  22470
# 204      5400       19          25  22625
#
# [205 rows x 26 columns]

# %%
df['make'] = Label_Encoder.fit_transform(df['make'])
df['make'].unique()
df['fuel-type'] = Label_Encoder.fit_transform(df['fuel-type'])
df['fuel-type'].unique()
df['aspiration'] = Label_Encoder.fit_transform(df['aspiration'])
df['aspiration'].unique()
df['num-of-doors'] = Label_Encoder.fit_transform(df['num-of-doors'])
df['num-of-doors'].unique()
df['body-style'] = Label_Encoder.fit_transform(df['body-style'])
df['body-style'].unique()
df['engine-type'] = Label_Encoder.fit_transform(df['engine-type'])
df['engine-type'].unique()
df['drive-wheels'] = Label_Encoder.fit_transform(df['drive-wheels'])
df['drive-wheels'].unique()
df['num-of-cylinders'] = Label_Encoder.fit_transform(df['num-of-cylinders'])
df['num-of-cylinders'].unique()
df['engine-location'] = Label_Encoder.fit_transform(df['engine-location'])
df['engine-location'].unique()
df['fuel-system'] = Label_Encoder.fit_transform(df['fuel-system'])
df['fuel-system'].unique()
# Out:
# array([5, 1, 4, 0, 7, 2, 3, 6])

# %%
df["fuel-type"] = pd.Categorical(df["fuel-type"]).codes
df["aspiration"] = pd.Categorical(df["aspiration"]).codes
df["num-of-doors"] = pd.Categorical(df["num-of-doors"]).codes
df["body-style"] = pd.Categorical(df["body-style"]).codes
df["drive-wheels"] = pd.Categorical(df["drive-wheels"]).codes
df["engine-location"] = pd.Categorical(df["engine-location"]).codes
df["fuel-system"] = pd.Categorical(df["fuel-system"]).codes

# %%
df

# %%
df['wheel-base']=df['wheel-base'].astype(int)
df['length']=df['wheel-base'].astype(int)
df['width']=df['wheel-base'].astype(int)
df['bore']=df['wheel-base'].astype(int)
df['stroke']=df['wheel-base'].astype(int)
df['engine-type']=df['engine-type'].astype(int)
df['num-of-cylinders']=df['num-of-cylinders'].astype(int)
df['compression-ratio']=df['compression-ratio'].astype(int)
df

# %%
df.isna()
# Out:
#      symboling  normalized-losses   make  fuel-type  aspiration  num-of-doors  \
# 0        False              False  False      False       False         False
# 1        False              False  False      False       False         False
# 2        False              False  False      False       False         False
# 3        False              False  False      False       False         False
# 4        False              False  False      False       False         False
# ..         ...                ...    ...        ...         ...           ...
# 200      False              False  False      False       False         False
# 201      False              False  False      False       False         False
# 202      False              False  False      False       False         False
# 203      False              False  False      False       False         False
# 204      False              False  False      False       False         False
#
#      body-style  drive-wheels  engine-location  wheel-base  ...  engine-size  \
# 0         False         False            False       False  ...        False
# 1         False         False            False       False  ...        False
# 2         False         False            False       False  ...        False
# 3         False         False            False       False  ...        False
# 4         False         False            False       False  ...        False
# ..          ...           ...              ...         ...  ...          ...
# 200       False         False            False       False  ...        False
# 201       False         False            False       False  ...        False
# 202       False         False            False       False  ...        False
# 203       False         False            False       False  ...        False
# 204       False         False            False       False  ...        False
#
#      fuel-system   bore  stroke  compression-ratio  horsepower  peak-rpm  \
# 0          False  False   False              False       False     False
# 1          False  False   False              False       False     False
# 2          False  False   False              False       False     False
# 3          False  False   False              False       False     False
# 4          False  False   False              False       False     False
# ..           ...    ...     ...                ...         ...       ...
# 200        False  False   False              False       False     False
# 201        False  False   False              False       False     False
# 202        False  False   False              False       False     False
# 203        False  False   False              False       False     False
# 204        False  False   False              False       False     False
#
#      city-mpg  highway-mpg  price
# 0       False        False  False
# 1       False        False  False
# 2       False        False  False
# 3       False        False  False
# 4       False        False  False
# ..        ...          ...    ...
# 200     False        False  False
# 201     False        False  False
# 202     False        False  False
# 203     False        False  False
# 204     False        False  False
#
# [205 rows x 26 columns]

# %%
df['normalized-losses'] = df['normalized-losses'].replace('?',np.nan)
df['bore'] = df['bore'].replace('?',np.nan)
df['stroke'] = df['stroke'].replace('?',np.nan)
df['horsepower'] = df['horsepower'].replace('?',np.nan)
df['peak-rpm'] = df['peak-rpm'].replace('?',np.nan)
df['price'] = df['price'].replace('?',np.nan)
df
# Out:
#      symboling normalized-losses  make  fuel-type  aspiration  num-of-doors  \
# 0            3               NaN     0          1           0             2
# 1            3               NaN     0          1           0             2
# 2            1               NaN     0          1           0             2
# 3            2               164     1          1           0             1
# 4            2               164     1          1           0             1
# ..         ...               ...   ...        ...         ...           ...
# 200         -1                95    21          1           0             1
# 201         -1                95    21          1           1             1
# 202         -1                95    21          1           0             1
# 203         -1                95    21          0           1             1
# 204         -1                95    21          1           1             1
#
#      body-style  drive-wheels  engine-location  wheel-base  ...  engine-size  \
# 0             0             2                0          88  ...          130
# 1             0             2                0          88  ...          130
# 2             2             2                0          94  ...          152
# 3             3             1                0          99  ...          109
# 4             3             0                0          99  ...          136
# ..          ...           ...              ...         ...  ...          ...
# 200           3             2                0         109  ...          141
# 201           3             2                0         109  ...          141
# 202           3             2                0         109  ...          173
# 203           3             2                0         109  ...          145
# 204           3             2                0         109  ...          141
#
#      fuel-system  bore  stroke  compression-ratio  horsepower  peak-rpm  \
# 0              5    88      88                  9         111      5000
# 1              5    88      88                  9         111      5000
# 2              5    94      94                  9         154      5000
# 3              5    99      99                 10         102      5500
# 4              5    99      99                  8         115      5500
# ..           ...   ...     ...                ...         ...       ...
# 200            5   109     109                  9         114      5400
# 201            5   109     109                  8         160      5300
# 202            5   109     109                  8         134      5500
# 203            3   109     109                 23         106      4800
# 204            5   109     109                  9         114      5400
#
#      city-mpg  highway-mpg  price
# 0          21           27  13495
# 1          21           27  16500
# 2          19           26  16500
# 3          24           30  13950
# 4          18           22  17450
# ..        ...          ...    ...
# 200        23           28  16845
# 201        19           25  19045
# 202        18           23  21485
# 203        26           27  22470
# 204        19           25  22625
#
# [205 rows x 26 columns]

# %%
df['normalized-losses'].fillna(0,inplace=True)
df['bore'].fillna(0,inplace=True)
df['stroke'].fillna(0,inplace=True)
df['horsepower'].fillna(0,inplace=True)
df['peak-rpm'].fillna(0,inplace=True)
df['price'].fillna(0,inplace=True)
df
# Out:
#      symboling normalized-losses  make  fuel-type  aspiration  num-of-doors  \
# 0            3                 0     0          1           0             2
# 1            3                 0     0          1           0             2
# 2            1                 0     0          1           0             2
# 3            2               164     1          1           0             1
# 4            2               164     1          1           0             1
# ..         ...               ...   ...        ...         ...           ...
# 200         -1                95    21          1           0             1
# 201         -1                95    21          1           1             1
# 202         -1                95    21          1           0             1
# 203         -1                95    21          0           1             1
# 204         -1                95    21          1           1             1
#
#      body-style  drive-wheels  engine-location  wheel-base  ...  engine-size  \
# 0             0             2                0          88  ...          130
# 1             0             2                0          88  ...          130
# 2             2             2                0          94  ...          152
# 3             3             1                0          99  ...          109
# 4             3             0                0          99  ...          136
# ..          ...           ...              ...         ...  ...          ...
# 200           3             2                0         109  ...          141
# 201           3             2                0         109  ...          141
# 202           3             2                0         109  ...          173
# 203           3             2                0         109  ...          145
# 204           3             2                0         109  ...          141
#
#      fuel-system  bore  stroke  compression-ratio  horsepower  peak-rpm  \
# 0              5    88      88                  9         111      5000
# 1              5    88      88                  9         111      5000
# 2              5    94      94                  9         154      5000
# 3              5    99      99                 10         102      5500
# 4              5    99      99                  8         115      5500
# ..           ...   ...     ...                ...         ...       ...
# 200            5   109     109                  9         114      5400
# 201            5   109     109                  8         160      5300
# 202            5   109     109                  8         134      5500
# 203            3   109     109                 23         106      4800
# 204            5   109     109                  9         114      5400
#
#      city-mpg  highway-mpg  price
# 0          21           27  13495
# 1          21           27  16500
# 2          19           26  16500
# 3          24           30  13950
# 4          18           22  17450
# ..        ...          ...    ...
# 200        23           28  16845
# 201        19           25  19045
# 202        18           23  21485
# 203        26           27  22470
# 204        19           25  22625
#
# [205 rows x 26 columns]

# %%
df.shape

# %%
x = df.drop(['price'],axis = 1)
x
# Out:
#      symboling normalized-losses  make  fuel-type  aspiration  num-of-doors  \
# 0            3                 0     0          1           0             2
# 1            3                 0     0          1           0             2
# 2            1                 0     0          1           0             2
# 3            2               164     1          1           0             1
# 4            2               164     1          1           0             1
# ..         ...               ...   ...        ...         ...           ...
# 200         -1                95    21          1           0             1
# 201         -1                95    21          1           1             1
# 202         -1                95    21          1           0             1
# 203         -1                95    21          0           1             1
# 204         -1                95    21          1           1             1
#
#      body-style  drive-wheels  engine-location  wheel-base  ...  \
# 0             0             2                0          88  ...
# 1             0             2                0          88  ...
# 2             2             2                0          94  ...
# 3             3             1                0          99  ...
# 4             3             0                0          99  ...
# ..          ...           ...              ...         ...  ...
# 200           3             2                0         109  ...
# 201           3             2                0         109  ...
# 202           3             2                0         109  ...
# 203           3             2                0         109  ...
# 204           3             2                0         109  ...
#
#      num-of-cylinders  engine-size  fuel-system  bore  stroke  \
# 0                   2          130            5    88      88
# 1                   2          130            5    88      88
# 2                   3          152            5    94      94
# 3                   2          109            5    99      99
# 4                   1          136            5    99      99
# ..                ...          ...          ...   ...     ...
# 200                 2          141            5   109     109
# 201                 2          141            5   109     109
# 202                 3          173            5   109     109
# 203                 3          145            3   109     109
# 204                 2          141            5   109     109
#
#      compression-ratio  horsepower  peak-rpm  city-mpg  highway-mpg
# 0                    9         111      5000        21           27
# 1                    9         111      5000        21           27
# 2                    9         154      5000        19           26
# 3                   10         102      5500        24           30
# 4                    8         115      5500        18           22
# ..                 ...         ...       ...       ...          ...
# 200                  9         114      5400        23           28
# 201                  8         160      5300        19           25
# 202                  8         134      5500        18           23
# 203                 23         106      4800        26           27
# 204                  9         114      5400        19           25
#
# [205 rows x 25 columns]

# %%
y = df['price']
y

# %%
xtrain,xtest,ytrain,ytest = train_test_split(x,y,test_size=0.2)

# %%
xtrain,xtest,ytrain,ytest

# %%
final_model = LinearRegression()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-30-50f94f4d3091> in <module>
# ----> 1 final_model = LinearRegression()
#
# NameError: name 'LinearRegression' is not defined

# %%
final_model.fit(xtrain,ytrain,sample_weight=2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-31-05ed2b1eb205> in <module>
# ----> 1 final_model.fit(xtrain,ytrain,sample_weight=2)
#
# NameError: name 'final_model' is not defined

# %%
y_pred = final_model.predict(x)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-32-a5635a446166> in <module>
# ----> 1 y_pred = final_model.predict(x)
#
# NameError: name 'final_model' is not defined

# %%
y_pred
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-33-3aaf935e6aec> in <module>
# ----> 1 y_pred
#
# NameError: name 'y_pred' is not defined

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score

# %%
mse = mean_squared_error(y,y_pred)
mae = mean_absolute_error(y,y_pred)
r2_score = r2_score(y,y_pred)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-35-a267f86bb96d> in <module>
# ----> 1 mse = mean_squared_error(y,y_pred)
#       2 mae = mean_absolute_error(y,y_pred)
#       3 r2_score = r2_score(y,y_pred)
#
# NameError: name 'y_pred' is not defined

# %%
mse
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-36-8ba39e77e893> in <module>
# ----> 1 mse
#
# NameError: name 'mse' is not defined

# %%
mae
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-37-71e26892b380> in <module>
# ----> 1 mae
#
# NameError: name 'mae' is not defined

# %%
r2_score
# Out:
# <function sklearn.metrics._regression.r2_score(y_true, y_pred, *, sample_weight=None, multioutput='uniform_average', force_finite=True)>
